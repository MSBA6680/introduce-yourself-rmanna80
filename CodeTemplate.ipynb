# %%
import time

print("Maximizing CPU usage...")

for i in range(0, 101, 10):
    print(f"CPU Usage: {i}%")
    time.sleep(0.3)

print("Laptop will explode in 3... 2... 1...")
time.sleep(3)
print("Just kidding — your laptop survived.")
# Out:
# Maximizing CPU usage...
# CPU Usage: 0%
# CPU Usage: 10%
# CPU Usage: 20%
# CPU Usage: 30%
# CPU Usage: 40%
# CPU Usage: 50%
# CPU Usage: 60%
# CPU Usage: 70%
# CPU Usage: 80%
# CPU Usage: 90%
# CPU Usage: 100%
# Laptop will explode in 3... 2... 1...
# Just kidding — your laptop survived.
